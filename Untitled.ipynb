# %%
import matplotlib.pyplot as plt

# Your data and SQL query results
dates = ["Date 1", "Date 2", "Date 3"]  
users_before = [10, 20, 15]  
users_after = [25, 30, 35]  

# Create a line chart
plt.plot(dates, users_before, label="Users Before")
plt.plot(dates, users_after, label="Users After")

# Customize the chart (add labels, title, legend, etc.)
plt.xlabel("Date")
plt.ylabel("User Count")
plt.title("Daily Average Users Before and After Feature Change")
plt.legend()

# Show the chart
plt.show()
